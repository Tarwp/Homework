# %%
##ข้อที่ 1
num = int(input('Enter Your Number'))
if num == 0 :
  print('เลขศูนย์')

elif num % 2 == 0 :
  print('เลขคู่')

else :
  print('เลขคี่')
# Out:
# Enter Your Number3
# เลขคี่

# %%
##ข้อที่2
num1 = float(input('Enter Your Number'))

while num1 != 0:
 
 num2 = float(input('Enter Your Number'))
 if num1 != 0 :
   ans = num1//num2
   print(ans)

# %%
##ข้อ3
num3 = []
num4 = int(input('Enter YourNumber'))
while num4 != 0 :
  if num4 != 0 :
    num3.append(num4)
  num4 = int(input('Enter YourNumber'))
print(num3)
print(sum(num3)//len(num3))

# %%
##ข้อ4
check = int(input('Enter Your Number'))
if check % 7 == 0 :
  print('หาร 7 ลงตัว')
else :
  print('หาร 7 ไม่ลงตัว')
# Out:
# Enter Your Number20
# หาร 7 ไม่ลงตัว

# %%
##ข้อ5
py1 = int(input('Enter Your Number'))
py2 = int(input('Enter Your Number'))
py3 = int(input('Enter Your Number'))
a = py1
b = py2
c = py3
if a**2 + b**2 == c**2 :
  print('True')
else : 
  print('False')
# Out:
# Enter Your Number3
# Enter Your Number4
# Enter Your Number5
# True

# %%
##ข้อที่6
py1 = int(input('Enter Your Number'))
py2 = int(input('Enter Your Number'))
py3 = int(input('Enter Your Number'))
a = py1
b = py2
c = py3
if a**2 + b**2 < c**2 :
  print('สามเหลี่ยมมุมเเหลม')
elif a**2 + b**2 > c**2 :
  print('สามเหลี่ยมมุมป้าน')
else :
  print('สามเหลี่ยมมุมฉาก')
# Out:
# Enter Your Number2
# Enter Your Number2
# Enter Your Number5
# สามเหลี่ยมมุมเเหลม

# %%
##ข้อที่7
bill = []
count = 0

while count != 3 and 1000 <= price <= 5000 :
  price = int(input('Enter Price'))
  count += 1
  bill.append(price)
  Total_bill = sum(bill)  
if Total_bill >= 5000 and Total_bill <= 12000 :
  Totalprice = Total_bill * 0.85 
  print('Total Price is :', Totalprice)
elif Total_bill >= 12000 :
  Totalprice = Total_bill * 0.75
  print('Total Price is :', Totalprice)
else :
  Totalprice = Total_bill
  print('Total Price is :', Totalprice)
# Out:
# Enter Price1000
# Enter Price1000
# Enter Price1000
# Total Price is : 3000

# %%
##ข้อที่ 8
bill = []
count = 0

while count != 4 and 1000 <= price <= 5000 :
  price = int(input('Enter Price'))
  count += 1
  bill.append(price)
  Total_bill = sum(bill)
promo = sum(bill[0:3])   
if promo >= 5000 and promo <= 12000 :
  Totalprice = Total_bill * 0.85 
  print('Total Price is :', Totalprice)
elif promo >= 12000 :
  Totalprice = Total_bill * 0.75
  print('Total Price is :', Totalprice)
else :
  Totalprice = Total_bill
  print('Total Price is :', Totalprice)
# Out:
# Enter Price2000
# Enter Price2000
# Enter Price1000
# Enter Price5000
# Total Price is : 8500.0

# %%
##ข้อที่ 9
bill = []
count = 0

while count != 4 :
  price = int(input('Enter Price'))
  if 1000 <= price <= 5000 :
   count += 1
   bill.append(price)
   Total_bill = sum(bill)
promo = sum(bill[0:3])
if promo >= 4000 and promo <= 9000 :
  Totalprice = Total_bill * 0.75 
  print('Total Price is :', Totalprice)
elif promo >= 9000 :
  Totalprice = Total_bill * 0.70
  print('Total Price is :', Totalprice)
else :
  Totalprice = Total_bill
  print('Total Price is :', Totalprice)
# Out:
# Enter Price4000
# Enter Price4000
# Enter Price4000
# Enter Price100
# Enter Price100
# Enter Price2000
# Total Price is : 9800.0

# %%
##ข้อที่ 10
bill = []
count = 0

while count != 4 :
  price = int(input('Enter Price'))
  if 1000 <= price <= 5000 :
   count += 1
   bill.append(price)
   Total_bill = sum(bill)
promo = sum(bill[0:3])
if promo >= 4000 and promo <= 9000 :
  Totalprice = Total_bill * 0.75 
elif promo >= 9000 :
  Totalprice = Total_bill * 0.70
else :
  Totalprice = Total_bill
credit = input('How would you like to pay?(Cash/Credit Card)')
if credit == 'Card' :
  Totalprice = Totalprice * 0.95
  print('Total Price is :', Totalprice)
else :
  print('Total Price is :', Totalprice)
# Out:
# Enter Price2000
# Enter Price2000
# Enter Price2000
# Enter Price2000
# How would you like to pay?(Cash/Credit Card)Card
# Total Price is : 5700.0

# %%
## ข้อที่ 11
word = input('Any Word you like(>7 letters)')
if len(word) > 7 :
  print(word.swapcase())
else :
  print(word)
# Out:
# Any Word you like(>7 letters)ttttt
# ttttt

# %%
##ข้อที่ 12
word2 = input('Enter any word :')
word3 = input('Enter any word :')
word4 = input('Enter any word :')
word5 = input('Enter any word :')
check_word = [word2, word3, word4, word5]


sorted(check_word)
# Out:
# Enter any word :rrrrr
# Enter any word :rrrrrrr
# Enter any word :r
# Enter any word :rrr
# ['r', 'rrr', 'rrrrr', 'rrrrrrr']

# %%
##ข้อที่ 13

hr = int(input('Enter number :'))
min = int(input('Enter numer :'))
price1 = hr * 150
price2 = min * 2
print(price1 + price2)
# Out:
# Enter number :2
# Enter numer :30
# 360

# %%
##ข้อที่ 14
price = 0
 
hr = int(input('Enter number :'))
min = int(input('Enter numer :'))

if hr == 1 :
  price = 0 
elif hr > 1 and min >= 15 :
  hr = hr + 1
  price = (hr-1) * 300
else :
  price = hr * 300


print(hr, price)
# Out:
# Enter number :2
# Enter numer :0
# 2 600

# %%
birds = 0
cows = 0
Totalprice = 0
head = int(input('Enter head No. :'))
legs = int(input('Enter legs No. :'))
birds1 = legs - (head * 2)
cows = birds1 / 2
birds2 = head - cows
Totalprice = (birds2*150)+(cows*220)
print(birds2, cows, Totalprice)
print(birds2 * 2 + cows * 4)
# Out:
# Enter head No. :10
# Enter legs No. :26
# 7.0 3.0 1710.0
# 26.0
